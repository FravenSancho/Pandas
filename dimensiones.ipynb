# %%
import pandas #importamos la librería

primerdataset = {
    'autos': ["Toyota", "Renault", "Nissan"],
    'precios': [3000, 4000, 5000]

}

test1 = pandas.DataFrame(primerdataset)
print(test1)
# Out:
#      autos  precios
# 0   Toyota     3000
# 1  Renault     4000
# 2   Nissan     5000

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Fraven Sancho Lazo uwu!")
plt.show()

# %%
import pandas

grupo_animales = {
    'color': ["rojo", "negro", "verde", "blanco"],
    'peso' : [54,13,14,21],
    'raza' : ["pequinez", "san fernando", "bulldog", "sin raza"]
}

grupo_1 = pandas.DataFrame(grupo_animales)
grupo_1
# Out:
#     color  peso          raza
# 0    rojo    54      pequinez
# 1   negro    13  san fernando
# 2   verde    14       bulldog
# 3  blanco    21      sin raza

# %%
import pandas

student_group = pandas.DataFrame(
    {
        'nombre': ["Fraven", "Alicia", "Rocio"],
     'edad': [26,23,21],
     'carrera': ["Ingeniería de Sistemas", "Psicología", "Administración"]
    }
)
student_group
# Out:
#    nombre  edad                 carrera
# 0  Fraven    26  Ingeniería de Sistemas
# 1  Alicia    23              Psicología
# 2   Rocio    21          Administración

# %%
import pandas as pd

transport_group = pd.DataFrame(
    {
        'nombre' : ["Avión", "Auto", "Tren", "Caballo", "Carruaje"],
     'velocidad' : [2500, 3455, 23424, 2323,4555]
    }
)

transport_group['nombre']
# Out:
# 0       Avión
# 1        Auto
# 2        Tren
# 3     Caballo
# 4    Carruaje
# Name: nombre, dtype: object

# %%
frutas_group = pd.Series(
    [1,2,3]
)
frutas_group
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
celulares = pd.Series(
    
    ["Samsung", "Motorolla", "Blackberry"],
    index = ["a", "b", "c"]

)
#celulares
celulares["b"] #regresa al valor del index
# Out:
# 'Motorolla'

# %%
notas_group = pd.Series(
    
    {"dia1": 15,
     "dia2": 16,
     "dia3": 13}
#Si es un diccionario, tendras sus
#propias etiquetas
)
notas_group
# Out:
# dia1    15
# dia2    16
# dia3    13
# dtype: int64

# %%
nota_parcial = pd.Series(
    
    {"fraven": 15,
     "chedania": 20,
     "tina": 14,
     "roberto": 19},
     index = ["fraven", "chedania"]
)
nota_parcial
# Out:
# fraven      15
# chedania    20
# dtype: int64

# %%
comida_peruana = pd.DataFrame(
    {
    'name': ["Arroz con Pollo", "Ceviche", "Tallarines Rojos"],
    'costo': [15,20,30]
     },
     index = ["Muy rico", "Rico", "Delicioso"]
)
comida_peruana
# Out:
#                        name  costo
# Muy rico    Arroz con Pollo     15
# Rico                Ceviche     20
# Delicioso  Tallarines Rojos     30

# %%
rostro_group = pd.DataFrame(
    {
        'nombre': ["Ojos", "Boca", "Nariz", "Oidos"],
        'cantidad': [2,1,1,2]          
    },
    index = ["A1", "A2", "A3", "A4"]
)
#rostro_group
#rostro_group.loc[0:2]  #localizar 1 fila
#rostro_group.loc[[0,1]]
#rostro_group.loc[0:1]
rostro_group.loc["A1":"A2"]
# Out:
#    nombre  cantidad
# A1   Ojos         2
# A2   Boca         1

# %%
#Cargar archivos de un DataFrame
televisores = pd.read_csv(r'https://raw.githubusercontent.com/FravenSancho/Pandas/e2fe90fc02acb3050147e8a6cc7bf6a3ba2d36f8/techogar.csv')
televisores.head()
# Out:
#     Año  Computadora   Internet  Televisión      Cable   Teléfono
# 0  2001    11.777200   6.212087   91.897078  13.529983  40.331515
# 1  2002    15.207573   7.455098   93.592413  15.375804  45.358014
# 2  2004    18.001723   8.692415   91.689488  19.330399  24.740764
# 3  2005    18.558932   9.002206   92.816496  19.508416  22.264085
# 4  2006    20.622965  10.132403   93.360834  21.045569  19.458675

# %%
import pandas as pd

nombre_columnas = ['Perras','Zorras','Overlord','imbecil','tururu','asd']
#pd.options.display.max_rows = 6
group_tv = pd.read_csv(r'https://raw.githubusercontent.com/FravenSancho/Pandas/main/techogar.csv',
                       names=nombre_columnas,header=None)

#group_tv.head(10)
group_tv.tail()#para devolver últimas filas
# Out:
#    Perras         Zorras  ...         tururu            asd
# 10   2011  30.0363271932  ...  30.3530488283   8.0778186587
# 11   2012  32.1947170808  ...  32.2391834527   7.2606138873
# 12   2013  35.7928577436  ...  36.7301099546   6.4038952823
# 13   2014  38.2920147833  ...  38.1095449577  21.5964063404
# 14   2015  44.9111199168  ...  43.7452426929   4.1700716516
#
# [5 rows x 6 columns]

# %%
#Leer Archivos Tipo Json

ejemplo_jason = pd.read_json('https://www.w3schools.com/python/pandas/data.js')

ejemplo_jason
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# ..        ...    ...       ...       ...
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
perras = pd.read_json('https://www.w3schools.com/python/pandas/data.js')
perras
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# ..        ...    ...       ...       ...
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
other_example = pd.read_csv('https://raw.githubusercontent.com/FravenSancho/Pandas/main/techogar.csv')

other_example.head(10)
# Out:
#      Año  Computadora  ...      Cable   Teléfono
# 0   2001    11.777200  ...  13.529983  40.331515
# 1   2002    15.207573  ...  15.375804  45.358014
# 2   2004    18.001723  ...  19.330399  24.740764
# ..   ...          ...  ...        ...        ...
# 7   2009    26.757016  ...  27.200779   9.967356
# 8   2010    29.791100  ...  26.666277   9.248786
# 9   2011    30.036327  ...  30.353049   8.077819
#
# [10 rows x 6 columns]

# %%
example_json = {
    "Duracion" :{
        "0":60,
        "1":60,
        "2":60,
        "3":45,
        "4":45,
        "5":60
    
        
    }
}
example_json
# Out:
# {'Duracion': {'0': 60, '1': 60, '2': 60, '3': 45, '4': 45, '5': 60}}

# %%
titanic_data = pd.read_csv(r'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
edad = pd.Series(
    [22, 35, 56],
    name="Perras"
    )
edad
# Out:
# 0    22
# 1    35
# 2    56
# Name: Perras, dtype: int64

# %%
import pandas as pd

a = [1, 7 , 2]

prueba1 = pd.Series(a)#llamar solo a una columna
prueba1
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.3.5
